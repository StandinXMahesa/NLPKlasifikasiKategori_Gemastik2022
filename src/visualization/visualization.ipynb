# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("\\Users\\Mahesa\\Documents\\INI KULIAH BUKAN MAIN MAIN\\Competition\\GEMASTIK 2022\\Data Mining\\src\data\\newsdatasetshuffle_4000.csv")
print(df.shape)
df.head()
# Out:
# (4000, 6)
#    Unnamed: 0  source                                                url  \
# 0           0   detik  https://finance.detik.com/berita-ekonomi-bisni...
# 1           1   detik  https://news.detik.com/foto-news/d-5795911/sec...
# 2           2   detik  https://finance.detik.com/berita-ekonomi-bisni...
# 3           3     cnn  https://www.cnnindonesia.com/nasional/20191029...
# 4           4  kompas  http://nasional.kompas.com/read/2022/09/23/093...
#
#                                                title              timestamp  \
# 0    Stok Gula Aman, Pabrik Makanan Siap Ngebut Lagi  23 Apr 2021 13:01 WIB
# 1  Secuplik Nestapa Ethiopia, Negara Miskin yang ...  03 Nov 2021 22:36 WIB
# 2       Ssstt!! Ini Rahasia Tajir Jual-Beli Properti  16 Des 2021 16:04 WIB
# 3  Menteri Era SBY Yakin Nadiem Makarim Majukan P...    2022-10-20 12:37:15
# 4  Dewan Kolonel Vs Dewan Kopral, Perang Dukungan...  23/09/2022, 09:37 WIB
#
#        label
# 0   industri
# 1     perang
# 2   properti
# ...

# %%
df['label'].value_counts()
# Out:
# industri        800
# perang          800
# properti        800
# teknologi       800
# pemerintahan    800
# Name: label, dtype: int64

# %%
df['label'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
cnn_bilstm = [0.67,0.69,0.65,0.66,0.79]
cnn_lstm = [0.54,0.58,0.53,0.53,0.9]
indobert = [0.71,0.76,0.72,0.71,0.22]
uncasedbert = [0.76,0.8,0.75,0.76,0.33]
xgboost = [0.75,0.75,0.74,0.74,0.69]
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
sns.set(font_scale=2.0)
plt.figure(figsize=(7,5))
data = np.array([[0.76,0.8,0.75,0.76,0.33],
                 [0.75,0.75,0.74,0.74,0.69],
                 [0.71,0.76,0.72,0.71,0.22],
                 [0.67,0.69,0.65,0.66,0.79],
                 [0.54,0.58,0.53,0.53,0.9]])
plt.title("\nHeatmap Sistem Model Training Evaluasi\n")
df = pd.DataFrame(data, index = ['UncasedBERT', 'XGBoost', 'IndoBERT', 'CNN-biLSTM', 'CNN-LSTM'], 
                  columns= ['Acc','Prec','Recall','F1','Loss'])
sns.heatmap(df,annot=True,cmap='YlGn',annot_kws={'size': 25})
# Out:
# <AxesSubplot:title={'center':'\nHeatmap Sistem Model Training Evaluasi\n'}>

# %%
import cv2

Image1 = cv2.imread('\\Users\\Mahesa\\Documents\\INI KULIAH BUKAN MAIN MAIN\\Competition\\GEMASTIK 2022\\Data Mining\\src\\img\\Classification_Reporth\\cm_xgboost.jpg')
Image2 = cv2.imread('\\Users\\Mahesa\\Documents\\INI KULIAH BUKAN MAIN MAIN\\Competition\\GEMASTIK 2022\\Data Mining\\src\\img\\Classification_Reporth\\cm_uncasedbert.jpg')
Image3 = cv2.imread('\\Users\\Mahesa\\Documents\\INI KULIAH BUKAN MAIN MAIN\\Competition\\GEMASTIK 2022\\Data Mining\\src\\img\\Classification_Reporth\\cm_indoBERp2.jpg')
Image4 = cv2.imread('\\Users\\Mahesa\\Documents\\INI KULIAH BUKAN MAIN MAIN\\Competition\\GEMASTIK 2022\\Data Mining\\src\\img\\Classification_Reporth\\cm_cnnlstm.jpg')
Image5 = cv2.imread('\\Users\\Mahesa\\Documents\\INI KULIAH BUKAN MAIN MAIN\\Competition\\GEMASTIK 2022\\Data Mining\\src\\img\\Classification_Reporth\\cm_xgboost.jpg')
img = [Image5,Image2,Image3,Image4,Image5]
rows = 2
cols = 3
fig = plt.figure(figsize=(10, 7))
plt.imshow(img[0])
# for k,i in enumerate(img):
#     fig.add_subplot(rows, cols, 1)
#     plt.imshow(i)
    
# Image2 = cv2.imread('Image2.jpg')
# Image3 = cv2.imread('Image3.jpg')
# Image4 = cv2.imread('Image4.jpg')
